# %% [markdown]
# # Corrected Feature Extraction Pipeline
# - the voltammograms needs to be shfted!
# - the peak of pyoc is somewhere at -0.4V
# - in the real raw dataset, we need to create a correction, therefore we would consider the mean of the last signals with small dillutions; that value would be the correction constant.
#
# Dataset for lab signals: `Standard calibration in culture media_extended.xlsx`
#
# Dataset for real signals: `Date P.aeruginosa Clinic 788 + ATCC.xlsx`

# %%
from voltammogram_signal import Signal
import pandas as pd

# %%
df = pd.read_excel("datasets/Date P.aeruginosa Clinic 788 + ATCC.xlsx", sheet_name="788 raw")
df.head()
# Out:
#          6h Clinic_6 h nediluat_1  \
# 0         V                    µA
# 1 -0.600097              0.675497
# 2 -0.595262              0.678996
# 3 -0.590427              0.654497
# 4 -0.585592              0.631747
#
#   Clinic_6 h nediluat_1 - moving average baseline Clinic_6 h nediluat_2  \
# 0                                              µA                    µA
# 1                                               0              0.689496
# 2                                        0.045198              0.699996
# 3                                        0.037379              0.678996
# 4                                        0.031308              0.661497
#
#   Clinic_6 h nediluat_2 - moving average baseline Clinic_6 h nediluat_3  \
# 0                                              µA                    µA
# 1                                               0              0.626497
# 2                                        0.047368              0.626497
# ...

# %%
df.dropna(axis=1, inplace=True)
df.head()
# Out:
#          6h Clinic_6 h nediluat_1  \
# 0         V                    µA
# 1 -0.600097              0.675497
# 2 -0.595262              0.678996
# 3 -0.590427              0.654497
# 4 -0.585592              0.631747
#
#   Clinic_6 h nediluat_1 - moving average baseline Clinic_6 h nediluat_2  \
# 0                                              µA                    µA
# 1                                               0              0.689496
# 2                                        0.045198              0.699996
# 3                                        0.037379              0.678996
# 4                                        0.031308              0.661497
#
#   Clinic_6 h nediluat_2 - moving average baseline Clinic_6 h nediluat_3  \
# 0                                              µA                    µA
# 1                                               0              0.626497
# 2                                        0.047368              0.626497
# ...

# %%
print(df.columns)
# Out:
# Index(['6h', 'Clinic_6 h nediluat_1',
#        'Clinic_6 h nediluat_1 - moving average baseline',
#        'Clinic_6 h nediluat_2',
#        'Clinic_6 h nediluat_2 - moving average baseline',
#        'Clinic_6 h nediluat_3',
#        'Clinic_6 h nediluat_3 - moving average baseline', '9h',
#        'Clinic_9 h nediluat_1',
#        'Clinic_9 h nediluat_1 - moving average baseline',
#        ...
#        'Clinic_24 h diluat 1/32_2',
#        'Clinic_24 h diluat 1/32_2 - moving average baseline',
#        'Clinic_24 h diluat 1/32_3',
#        'Clinic_24 h diluat 1/32_3 - moving average baseline',
#        'Clinic_24 h diluat 1/64_1',
#        'Clinic_24 h diluat 1/64_1 - moving average baseline',
#        'Clinic_24 h diluat 1/64_2',
#        'Clinic_24 h diluat 1/64_2 - moving average baseline',
#        'Clinic_24 h diluat 1/64_3',
#        'Clinic_24 h diluat 1/64_3 - moving average baseline'],
#       dtype='str', length=138)

# %%
normalized_currents = df[[col for col in df.columns if 'moving average baseline' in col]]
normalized_currents.head()
# Out:
#   Clinic_6 h nediluat_1 - moving average baseline  \
# 0                                              µA
# 1                                               0
# 2                                        0.045198
# 3                                        0.037379
# 4                                        0.031308
#
#   Clinic_6 h nediluat_2 - moving average baseline  \
# 0                                              µA
# 1                                               0
# 2                                        0.047368
# 3                                        0.041116
# 4                                        0.038363
#
#   Clinic_6 h nediluat_3 - moving average baseline  \
# 0                                              µA
# 1                                               0
# 2                                        0.039375
# 3                                        0.037625
# 4                                        0.023624
#
# ...

# %%
normalized_currents.drop(index=0, inplace=True, axis=0)
normalized_currents.head()
# Out:
#   Clinic_6 h nediluat_1 - moving average baseline  \
# 1                                               0
# 2                                        0.045198
# 3                                        0.037379
# 4                                        0.031308
# 5                                        0.014737
#
#   Clinic_6 h nediluat_2 - moving average baseline  \
# 1                                               0
# 2                                        0.047368
# 3                                        0.041116
# 4                                        0.038363
# 5                                         0.02861
#
#   Clinic_6 h nediluat_3 - moving average baseline  \
# 1                                               0
# 2                                        0.039375
# 3                                        0.037625
# 4                                        0.023624
# 5                                        0.011373
#
# ...

# %%
times = [
    6,
    6,
    6,
    9,
    9,
    9,
    9,
    12,
    12,
    12,
    12,
    12,
    12,
    12,
    12,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    16,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    20,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24,
    24
]

df.iloc[1:, 0]
# Out:
# 1     -0.600097
# 2     -0.595262
# 3     -0.590427
# 4     -0.585592
# 5     -0.580757
#          ...
# 225    0.482979
# 226    0.487814
# 227    0.492649
# 228    0.497484
# 229    0.502319
# Name: 6h, Length: 229, dtype: object

# %%
Signal.set_common_potential_E(df.iloc[1:, 0])
len(Signal.E)
# Out:
# 229

# %%
signals = []

for i, col in enumerate(normalized_currents.columns):
    signal = Signal(normalized_currents[col].values)
    signals.append(signal)
    signal.pplot(start=10, end=200, title=f"Signal ID: {i}, Time: {times[i]}h")
